# %% [markdown]
# # Bitcoin Price Forecasting with Prophet
#
# This notebook demonstrates how to load and forecast Bitcoin price data using utility functions from `bitcoin_utils.py`.

# %%
df = load_bitcoin_data("btc_prices.csv")

# %%
# Import helper functions from bitcoin_utils.py
import sys
sys.path.append(".")

from bitcoin_utils import (
    load_bitcoin_data,
    train_prophet_model,
    make_forecast,
    plot_forecast,
    plot_forecast_components
)

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data
df = load_bitcoin_data("btc_prices.csv")  # Replace with actual CSV file

# Train model
model = train_prophet_model(df)

# Forecast
forecast = make_forecast(model, periods=30)

# Plot forecast and components
plot_forecast(model, forecast)
plot_forecast_components(model, forecast)
# Out:
# 14:48:16 - cmdstanpy - INFO - Chain [1] start processing
# 14:48:17 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',
# ...
